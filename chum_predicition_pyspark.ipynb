# %%
import os
os.environ['PYSPARK_DRIVER_JAVA_OPTIONS'] = '-Djava.security.manager=allow'
os.environ['PYSPARK_EXECUTOR_JAVA_OPTIONS'] = '-Djava.security.manager=allow'

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder \
    .appName("Churn Prediction with PySpark") \
    .getOrCreate()
# Out:
# c:\Users\lucia\Documents\coding stuff\data_analysis\venv\Lib\site-packages\pyspark\testing\utils.py:127: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()

# %%
import pyspark
print(pyspark.__version__)
# Out:
# 4.2.0

# %%
spark.stop()

# %%
df20_test = spark.read.csv("data/churn-bigml-20.csv", header=True, inferSchema=True)
df80_train = spark.read.csv("data/churn-bigml-80.csv", header=True, inferSchema=True)

#Pyspark is not pysparking
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperationException             Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df20_test = spark.read.csv("data/churn-bigml-20.csv", header=True, inferSchema=True)
#       2 df80_train = spark.read.csv("data/churn-bigml-80.csv", header=True, inferSchema=True)
#       3
#       4 #Pyspark is not pysparking
#
# ...
